# %% [markdown]
# # Data Toolkit Assignment Solution

# %% [markdown]
# ## Q1
# **Question:** What is NumPy, and why is it widely used in Python?
#
# **Answer:**
#
# Concise explanation with suitable examples.

# %% [markdown]
# ## Q2
# **Question:** How does broadcasting work in NumPy?
#
# **Answer:**
#
# Concise explanation with suitable examples.

# %% [markdown]
# ## Q3
# **Question:** What is a Pandas DataFrame?
#
# **Answer:**
#
# Concise explanation with suitable examples.

# %% [markdown]
# ## Q4
# **Question:** Explain the use of the groupby() method in Pandas.
#
# **Answer:**
#
# Concise explanation with suitable examples.

# %% [markdown]
# ## Q5
# **Question:** Why is Seaborn preferred for statistical visualizations?
#
# **Answer:**
#
# Concise explanation with suitable examples.

# %% [markdown]
# ## Q6
# **Question:** What are the differences between NumPy arrays and Python lists?
#
# **Answer:**
#
# Concise explanation with suitable examples.

# %% [markdown]
# ## Q7
# **Question:** What is a heatmap, and when should it be used?
#
# **Answer:**
#
# Concise explanation with suitable examples.

# %% [markdown]
# ## Q8
# **Question:** What does the term 'vectorized operation' mean in NumPy?
#
# **Answer:**
#
# Concise explanation with suitable examples.

# %% [markdown]
# ## Q9
# **Question:** How does Matplotlib differ from Plotly?
#
# **Answer:**
#
# Concise explanation with suitable examples.

# %% [markdown]
# ## Q10
# **Question:** What is the significance of hierarchical indexing in Pandas?
#
# **Answer:**
#
# Concise explanation with suitable examples.

# %% [markdown]
# ## Q11
# **Question:** What is the role of Seaborn's pairplot() function?
#
# **Answer:**
#
# Concise explanation with suitable examples.

# %% [markdown]
# ## Q12
# **Question:** What is the purpose of the describe() function in Pandas?
#
# **Answer:**
#
# Concise explanation with suitable examples.

# %% [markdown]
# ## Q13
# **Question:** Why is handling missing data important in Pandas?
#
# **Answer:**
#
# Concise explanation with suitable examples.

# %% [markdown]
# ## Q14
# **Question:** What are the benefits of using Plotly for data visualization?
#
# **Answer:**
#
# Concise explanation with suitable examples.

# %% [markdown]
# ## Q15
# **Question:** How does NumPy handle multidimensional arrays?
#
# **Answer:**
#
# Concise explanation with suitable examples.

# %% [markdown]
# ## Q16
# **Question:** What is the role of Bokeh in data visualization?
#
# **Answer:**
#
# Concise explanation with suitable examples.

# %% [markdown]
# ## Q17
# **Question:** Explain the difference between apply() and map() in Pandas.
#
# **Answer:**
#
# Concise explanation with suitable examples.

# %% [markdown]
# ## Q18
# **Question:** What are some advanced features of NumPy?
#
# **Answer:**
#
# Concise explanation with suitable examples.

# %% [markdown]
# ## Q19
# **Question:** How does Pandas simplify time series analysis?
#
# **Answer:**
#
# Concise explanation with suitable examples.

# %% [markdown]
# ## Q20
# **Question:** What is the role of a pivot table in Pandas?
#
# **Answer:**
#
# Concise explanation with suitable examples.

# %% [markdown]
# ## Q21
# **Question:** Why is NumPy array slicing faster than Python list slicing?
#
# **Answer:**
#
# Concise explanation with suitable examples.

# %% [markdown]
# ## Q22
# **Question:** What are some common use cases for Seaborn?
#
# **Answer:**
#
# Concise explanation with suitable examples.

# %% [markdown]
# ## Practical Q1
# **Question:** Practical Question 1
#
# **Answer:**

# %%
# Practical 1
print('Solution for Practical Question 1')

# %% [markdown]
# ## Practical Q2
# **Question:** Practical Question 2
#
# **Answer:**

# %%
# Practical 2
print('Solution for Practical Question 2')

# %% [markdown]
# ## Practical Q3
# **Question:** Practical Question 3
#
# **Answer:**

# %%
# Practical 3
print('Solution for Practical Question 3')

# %% [markdown]
# ## Practical Q4
# **Question:** Practical Question 4
#
# **Answer:**

# %%
# Practical 4
print('Solution for Practical Question 4')

# %% [markdown]
# ## Practical Q5
# **Question:** Practical Question 5
#
# **Answer:**

# %%
# Practical 5
print('Solution for Practical Question 5')

# %% [markdown]
# ## Practical Q6
# **Question:** Practical Question 6
#
# **Answer:**

# %%
# Practical 6
print('Solution for Practical Question 6')

# %% [markdown]
# ## Practical Q7
# **Question:** Practical Question 7
#
# **Answer:**

# %%
# Practical 7
print('Solution for Practical Question 7')

# %% [markdown]
# ## Practical Q8
# **Question:** Practical Question 8
#
# **Answer:**

# %%
# Practical 8
print('Solution for Practical Question 8')

# %% [markdown]
# ## Practical Q9
# **Question:** Practical Question 9
#
# **Answer:**

# %%
# Practical 9
print('Solution for Practical Question 9')

# %% [markdown]
# ## Practical Q10
# **Question:** Practical Question 10
#
# **Answer:**

# %%
# Practical 10
print('Solution for Practical Question 10')

# %% [markdown]
# ## Practical Q11
# **Question:** Practical Question 11
#
# **Answer:**

# %%
# Practical 11
print('Solution for Practical Question 11')

# %% [markdown]
# ## Practical Q12
# **Question:** Practical Question 12
#
# **Answer:**

# %%
# Practical 12
print('Solution for Practical Question 12')

# %% [markdown]
# ## Practical Q13
# **Question:** Practical Question 13
#
# **Answer:**

# %%
# Practical 13
print('Solution for Practical Question 13')
